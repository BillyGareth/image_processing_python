# %% [markdown]
# # <font color='red'>Python:Image_Processing </font>

# %% [markdown]
# # <font color='blue'> Using pillows(PIL)module with matplotlib<font>

# %%
from PIL import Image

# %%
import matplotlib.pyplot as plt

# %%
img=Image.open('./billgates.jpg')

# %%
plt.imshow(img)

# %% [markdown]
# # <font color='orange'> Using matplotlib <font>

# %% [markdown]
# # <font color='blue'> using imread() and imshow()<font>

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.image as mpimg

# %%
img=mpimg.imread('./unity_pro.png')

# %%
plt.imshow(img)

# %% [markdown]
# # <font color='green'> Using imageio and matplotlib modules<font>

# %%
import imageio

# %%
from matplotlib import pyplot as plt

# %%
img=imageio.imread('./pro_build.PNG')

# %%
plt.imshow(img)
